# %% [markdown]
# # KISHU KUMAR
# # 2105549
# # CSE 24

# %%
import matplotlib.pyplot as plt 
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as pit
import numpy as np

ypoints=np.array((3,8,1,10))
pit.plot(ypoints,marker='o')
pit.show()

# %%
import matplotlib.pyplot as pit
import numpy as np
ypoints=np.array((3,8,1,10))
pit.plot(ypoints,linestyle="dotted")
pit.show()

# %%
pit.plot(ypoints,ls=':')

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array((80,85,90,95,100,105,110,115,120,125))
y=np.array((240,250,260,270,280,290,300,310,320,330))

plt.plot(x,y)
plt.title("sports watch data")
plt.xlabel("Average Pulse")
plt.ylabs("Calorie Burnage")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 10
#       8 plt.title("sports watch data")
#       9 plt.xlabel("Average Pulse")
# ---> 10 plt.ylabs("Calorie Burnage")
#      11 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylabs'

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={"family":"serif","color":"blue","size":20}
font2={"family":"serif","color":"darkred","size":15}

plt.title("sports watch data",fontdict=font1)
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("caloris burnage",fontdict=font2)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={"family":"serif","color":"blue","size":20}
font2={"family":"serif","color":"darkred","size":15}

plt.title("sports watch data",fontdict=font1)
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("caloris burnage",fontdict=font2)
plt.plot(x,y)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={"family":"serif","color":"blue","size":20}
font2={"family":"serif","color":"darkred","size":15}

plt.title("sports watch data",fontdict=font1)
plt.xlabel("average pulse",fontdict=font2)
plt.ylabel("caloris burnage",fontdict=font2)
plt.plot(x,y)
plt.grid(axis='x')

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)

#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,1,2)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")

#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])


plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,85,87,34,56,67,88,34,43,89,90,23,65])

plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,85,87,34,56,67,88,34,43,89,90,23,65])

plt.scatter(x,y)
plt.title("GRAPH 1")
plt.show()

x=np.array([1,2,5,4,87,99,34,76,88,23,34,23,65])
y=np.array([23,8,7,45,65,90,10,12,45,67,23,12,88])
plt.scatter(x,y)
plt.title("GRAPH 2")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,85,87,34,56,67,88,34,43,89,90,23,65])

plt.scatter(x,y,color="hotpink")
plt.title("GRAPH 1")
plt.show()

x=np.array([1,2,5,4,87,99,34,76,88,23,34,23,65])
y=np.array([23,8,7,45,65,90,10,12,45,67,23,12,88])
plt.scatter(x,y,color="#88c999")
plt.title("GRAPH 2")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.normal(170,10,210)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([35,25,25,15])

plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=np.random.random((12,12))
pit.imshow(data)
pit.title("2-D Heat Map")
plt.show()

# %%
data=np.random.random((12,12))
plt.imshow(data,cmap="autumn",interpolation="nearest")
plt.colorbar()
plt.title("Heatmap with color bar")
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)
sns.set()
uniform_data=np.random.rand(10,12)
ax=sns.heatmap(uniform_data,vmin=0,vmax=1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("iris")
df.head()

sns.boxplot(y=df["species"],x=df["sepal_length"]);
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("iris")
df.head()

sns.boxplot(y=df["species"],x=df["sepal_length"],width=0.3);
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot([0,1,2,3,4,5])
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_11380\628185923.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot([0,1,2,3,4,5],hist=False)
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_11380\2801471525.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5],hist=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

rs=np.random.RandomState(10)
d=rs.normal(size=100)

sns.histplot(d,kde=True,color="m")
# Out:
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("iris.csv")
plt.figure(figsize=(10, 5))
plt.plot(df['SepalLengthCm'],label='Sepal Length')
plt.plot(df['SepalWidthCm'],label='Sepal Width')
plt.title('Line Plot - Sepal Length and Width')
plt.xlabel('Index')
plt.ylabel('Size (cm)')
plt.legend()
plt.show()

# %%
plt.scatter(df['SepalLengthCm'], df['SepalWidthCm'])
plt.title('Scatter Plot - Sepal Length vs Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
sns.barplot(x='Species', y='SepalLengthCm', data=df)
plt.title('Bar Plot - Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
sns.histplot(df['SepalLengthCm'])
plt.title('Histogram - Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=df)
plt.title('Box Plot - Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# df = df.drop(columns=["Species"])
# Create heatmap
sns.heatmap(df.corr(),cmap='summer')
plt.title("Correlation Matrix of Iris Features")
plt.show()

# %%
#general purpose of integration
import scipy.integrate as integrate
import scipy.special as special
result=integrate.quad(lambda x:special.jv(2.5,x),0,4.5)
print(result)
# Out:
# (1.1178179380783253, 7.866317182537226e-09)

# %%
#general purpose of double integration
from scipy.integrate import dblquad
area=dblquad(lambda x,y:x*y, 0, 0.5, lambda x:0, lambda x: 1-2*x)
print(area)
# Out:
# (0.010416666666666668, 4.101620128472366e-16)

# %%
from scipy import misc
def fun(x):
    return x**2 +x**3

# %%
misc.derivative(fun,1.5,dx=1e-2)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_11380\855380821.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   misc.derivative(fun,1.5,dx=1e-2)
# 9.750100000000028

# %%
from scipy.misc import derivative
fun1=lambda x: x**2+3*x+2
fun2=lambda x:x**3+3*x+2
fun=[fun1,fun2]
for i in range(len(fun)):
    ans=derivative(fun[1],1)
    print("Derivative of {} function is".format(i+1),ans)
# Out:
# Derivative of 1 function is 7.0
# Derivative of 2 function is 7.0
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_11380\3565257166.py:6: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   ans=derivative(fun[1],1)

# %%
from scipy.optimize import root
from math import cos

def eqn(x):
    return x+cos(x)
myroot=root(eqn,0)
print(myroot.x)
# Out:
# [-0.73908513]

# %%
from scipy.optimize import minimize

def eqn(x):
    return x**2+x+2
mymin=minimize(eqn,0,method='BFGS')
print(mymin)
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 1.75
#         x: [-5.000e-01]
#       nit: 2
#       jac: [ 0.000e+00]
#  hess_inv: [[ 5.000e-01]]
#      nfev: 8
#      njev: 4

# %%
import numpy as np
x=np.linspace(0,10,num=11)
y=np.cos(x**2/9.0)
xnew=np.linspace(0,10,num=1001)
ynew=np.interp(xnew,x,y)
import matplotlib.pyplot as plt
plt.plot(xnew,ynew,'-',label='linear interp')
plt.plot(x,y,'o',label='data')
plt.legend(loc='best')
plt.show()
